# %%
import pygame
import pickle
import matplotlib.pyplot as plt
import numpy as np
#from env import register_env
from enum import IntEnum
import dill
from statistics import variance, mean, stdev

from matplotlib import pyplot as plt

import dill

import random

from itertools import product

import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable


from sklearn.preprocessing import MinMaxScaler

from collections import defaultdict

with open('Our_Mus.pkl','rb') as f:  # Python 3: open(..., 'wb')
    q1_1_ours, q1_2_ours, q1_3_ours, q2_1_ours, q2_2_ours, q2_3_ours, q3_1_ours, q3_2_ours, q3_3_ours, q4_1_ours, q4_2_ours, q4_3_ours, q5_1_ours, q5_2_ours, q5_3_ours,  q1_1_random, q1_2_random, q1_3_random, q2_1_random, q2_2_random, q2_3_random, q3_1_random, q3_2_random, q3_3_random, q4_1_random, q4_2_random, q4_3_random, q5_1_random, q5_2_random, q5_3_random, q1_1_NoPerturb, q1_2_NoPerturb, q1_3_NoPerturb, q2_1_NoPerturb, q2_2_NoPerturb, q2_3_NoPerturb, q3_1_NoPerturb, q3_2_NoPerturb, q3_3_NoPerturb, q4_1_NoPerturb, q4_2_NoPerturb, q4_3_NoPerturb, q5_1_NoPerturb, q5_2_NoPerturb, q5_3_NoPerturb = pickle.load(f)

with open('AL_Final_1.pkl','rb') as f:  # Python 3: open(..., 'wb')
    q1_1_random, q1_2_random, q1_3_random, q2_1_random, q2_2_random, q2_3_random, q3_1_random, q3_2_random, q3_3_random, q4_1_random, q4_2_random, q4_3_random, q5_1_random, q5_2_random, q5_3_random = pickle.load(f)


horizon = 100

q1_1_ours_mean = np.zeros(horizon)
q1_1_ours_std = np.zeros(horizon)
total_episodes = np.arange(horizon)

for i in range(horizon):

    q1_1_ours_mean[i] = np.mean(q1_1_ours[:,i])
    q1_1_ours_std[i] = np.std(q1_1_ours[:,i])/(np.sqrt(1000))
######################################################################
q1_2_ours_mean = np.zeros(horizon)
q1_2_ours_std = np.zeros(horizon)

for i in range(horizon):

    q1_2_ours_mean[i] = np.mean(q1_2_ours[:,i])
    q1_2_ours_std[i] = np.std(q1_2_ours[:,i])/(np.sqrt(1000))
######################################################################
q1_3_ours_mean = np.zeros(horizon)
q1_3_ours_std = np.zeros(horizon)

for i in range(horizon):

    q1_3_ours_mean[i] = np.mean(q1_3_ours[:,i])
    q1_3_ours_std[i] = np.std(q1_3_ours[:,i])/(np.sqrt(1000))
######################################################################
######################################################################
q2_1_ours_mean = np.zeros(horizon)
q2_1_ours_std = np.zeros(horizon)

for i in range(horizon):

    q2_1_ours_mean[i] = np.mean(q2_1_ours[:,i])
    q2_1_ours_std[i] = np.std(q2_1_ours[:,i])/(np.sqrt(1000))
######################################################################
q2_2_ours_mean = np.zeros(horizon)
q2_2_ours_std = np.zeros(horizon)

for i in range(horizon):

    q2_2_ours_mean[i] = np.mean(q2_2_ours[:,i])
    q2_2_ours_std[i] = np.std(q2_2_ours[:,i])/(np.sqrt(1000))
######################################################################
q2_3_ours_mean = np.zeros(horizon)
q2_3_ours_std = np.zeros(horizon)

for i in range(horizon):

    q2_3_ours_mean[i] = np.mean(q2_3_ours[:,i])
    q2_3_ours_std[i] = np.std(q2_3_ours[:,i])/(np.sqrt(1000))
######################################################################
######################################################################
q3_1_ours_mean = np.zeros(horizon)
q3_1_ours_std = np.zeros(horizon)

for i in range(horizon):

    q3_1_ours_mean[i] = np.mean(q3_1_ours[:,i])
    q3_1_ours_std[i] = np.std(q3_1_ours[:,i])/(np.sqrt(1000))
######################################################################
q3_2_ours_mean = np.zeros(horizon)
q3_2_ours_std = np.zeros(horizon)

for i in range(horizon):

    q3_2_ours_mean[i] = np.mean(q3_2_ours[:,i])
    q3_2_ours_std[i] = np.std(q3_2_ours[:,i])/(np.sqrt(1000))
######################################################################
q3_3_ours_mean = np.zeros(horizon)
q3_3_ours_std = np.zeros(horizon)

for i in range(horizon):

    q3_3_ours_mean[i] = np.mean(q3_3_ours[:,i])
    q3_3_ours_std[i] = np.std(q3_3_ours[:,i])/(np.sqrt(1000))
######################################################################
######################################################################
q4_1_ours_mean = np.zeros(horizon)
q4_1_ours_std = np.zeros(horizon)

for i in range(horizon):

    q4_1_ours_mean[i] = np.mean(q4_1_ours[:,i])
    q4_1_ours_std[i] = np.std(q4_1_ours[:,i])/(np.sqrt(1000))
######################################################################
q4_2_ours_mean = np.zeros(horizon)
q4_2_ours_std = np.zeros(horizon)

for i in range(horizon):

    q4_2_ours_mean[i] = np.mean(q4_2_ours[:,i])
    q4_2_ours_std[i] = np.std(q4_2_ours[:,i])/(np.sqrt(1000))
######################################################################
q4_3_ours_mean = np.zeros(horizon)
q4_3_ours_std = np.zeros(horizon)

for i in range(horizon):

    q4_3_ours_mean[i] = np.mean(q4_3_ours[:,i])
    q4_3_ours_std[i] = np.std(q4_3_ours[:,i])/(np.sqrt(1000))
######################################################################
######################################################################
q5_1_ours_mean = np.zeros(horizon)
q5_1_ours_std = np.zeros(horizon)

for i in range(horizon):

    q5_1_ours_mean[i] = np.mean(q5_1_ours[:,i])
    q5_1_ours_std[i] = np.std(q5_1_ours[:,i])/(np.sqrt(1000))
######################################################################
q5_2_ours_mean = np.zeros(horizon)
q5_2_ours_std = np.zeros(horizon)

for i in range(horizon):

    q5_2_ours_mean[i] = np.mean(q5_2_ours[:,i])
    q5_2_ours_std[i] = np.std(q5_2_ours[:,i])/(np.sqrt(1000))
######################################################################
q5_3_ours_mean = np.zeros(horizon)
q5_3_ours_std = np.zeros(horizon)

for i in range(horizon):

    q5_3_ours_mean[i] = np.mean(q5_3_ours[:,i])
    q5_3_ours_std[i] = np.std(q5_3_ours[:,i])/(np.sqrt(1000))
######################################################################
######################################################################
######################################################################
q1_1_random_mean = np.zeros(horizon)
q1_1_random_std = np.zeros(horizon)

for i in range(horizon):

    q1_1_random_mean[i] = np.mean(q1_1_random[:,i])
    q1_1_random_std[i] = np.std(q1_1_random[:,i])/(np.sqrt(1000))
######################################################################
q1_2_random_mean = np.zeros(horizon)
q1_2_random_std = np.zeros(horizon)

for i in range(horizon):

    q1_2_random_mean[i] = np.mean(q1_2_random[:,i])
    q1_2_random_std[i] = np.std(q1_2_random[:,i])/(np.sqrt(1000))
######################################################################
q1_3_random_mean = np.zeros(horizon)
q1_3_random_std = np.zeros(horizon)

for i in range(horizon):

    q1_3_random_mean[i] = np.mean(q1_3_random[:,i])
    q1_3_random_std[i] = np.std(q1_3_random[:,i])/(np.sqrt(1000))
######################################################################
######################################################################
q2_1_random_mean = np.zeros(horizon)
q2_1_random_std = np.zeros(horizon)

for i in range(horizon):

    q2_1_random_mean[i] = np.mean(q2_1_random[:,i])
    q2_1_random_std[i] = np.std(q2_1_random[:,i])/(np.sqrt(1000))
######################################################################
q2_2_random_mean = np.zeros(horizon)
q2_2_random_std = np.zeros(horizon)

for i in range(horizon):

    q2_2_random_mean[i] = np.mean(q2_2_random[:,i])
    q2_2_random_std[i] = np.std(q2_2_random[:,i])/(np.sqrt(1000))
######################################################################
q2_3_random_mean = np.zeros(horizon)
q2_3_random_std = np.zeros(horizon)

for i in range(horizon):

    q2_3_random_mean[i] = np.mean(q2_3_random[:,i])
    q2_3_random_std[i] = np.std(q2_3_random[:,i])/(np.sqrt(1000))
######################################################################
######################################################################
q3_1_random_mean = np.zeros(horizon)
q3_1_random_std = np.zeros(horizon)

for i in range(horizon):

    q3_1_random_mean[i] = np.mean(q3_1_random[:,i])
    q3_1_random_std[i] = np.std(q3_1_random[:,i])/(np.sqrt(1000))
######################################################################
q3_2_random_mean = np.zeros(horizon)
q3_2_random_std = np.zeros(horizon)

for i in range(horizon):

    q3_2_random_mean[i] = np.mean(q3_2_random[:,i])
    q3_2_random_std[i] = np.std(q3_2_random[:,i])/(np.sqrt(1000))
######################################################################
q3_3_random_mean = np.zeros(horizon)
q3_3_random_std = np.zeros(horizon)

for i in range(horizon):

    q3_3_random_mean[i] = np.mean(q3_3_random[:,i])
    q3_3_random_std[i] = np.std(q3_3_random[:,i])/(np.sqrt(1000))
######################################################################
######################################################################
q4_1_random_mean = np.zeros(horizon)
q4_1_random_std = np.zeros(horizon)

for i in range(horizon):

    q4_1_random_mean[i] = np.mean(q4_1_random[:,i])
    q4_1_random_std[i] = np.std(q4_1_random[:,i])/(np.sqrt(1000))
######################################################################
q4_2_random_mean = np.zeros(horizon)
q4_2_random_std = np.zeros(horizon)

for i in range(horizon):

    q4_2_random_mean[i] = np.mean(q4_2_random[:,i])
    q4_2_random_std[i] = np.std(q4_2_random[:,i])/(np.sqrt(1000))
######################################################################
q4_3_random_mean = np.zeros(horizon)
q4_3_random_std = np.zeros(horizon)

for i in range(horizon):

    q4_3_random_mean[i] = np.mean(q4_3_random[:,i])
    q4_3_random_std[i] = np.std(q4_3_random[:,i])/(np.sqrt(1000))
######################################################################
######################################################################
q5_1_random_mean = np.zeros(horizon)
q5_1_random_std = np.zeros(horizon)

for i in range(horizon):

    q5_1_random_mean[i] = np.mean(q5_1_random[:,i])
    q5_1_random_std[i] = np.std(q5_1_random[:,i])/(np.sqrt(1000))
######################################################################
q5_2_random_mean = np.zeros(horizon)
q5_2_random_std = np.zeros(horizon)

for i in range(horizon):

    q5_2_random_mean[i] = np.mean(q5_2_random[:,i])
    q5_2_random_std[i] = np.std(q5_2_random[:,i])/(np.sqrt(1000))
######################################################################
q5_3_random_mean = np.zeros(horizon)
q5_3_random_std = np.zeros(horizon)

for i in range(horizon):

    q5_3_random_mean[i] = np.mean(q5_3_random[:,i])
    q5_3_random_std[i] = np.std(q5_3_random[:,i])/(np.sqrt(1000))
######################################################################
######################################################################
######################################################################
q1_1_NoPerturb_mean = np.zeros(horizon)
q1_1_NoPerturb_std = np.zeros(horizon)

for i in range(horizon):

    q1_1_NoPerturb_mean[i] = np.mean(q1_1_NoPerturb[:,i])
    q1_1_NoPerturb_std[i] = np.std(q1_1_NoPerturb[:,i])/(np.sqrt(1000))
######################################################################
q1_2_NoPerturb_mean = np.zeros(horizon)
q1_2_NoPerturb_std = np.zeros(horizon)

for i in range(horizon):

    q1_2_NoPerturb_mean[i] = np.mean(q1_2_NoPerturb[:,i])
    q1_2_NoPerturb_std[i] = np.std(q1_2_NoPerturb[:,i])/(np.sqrt(1000))
######################################################################
q1_3_NoPerturb_mean = np.zeros(horizon)
q1_3_NoPerturb_std = np.zeros(horizon)

for i in range(horizon):

    q1_3_NoPerturb_mean[i] = np.mean(q1_3_NoPerturb[:,i])
    q1_3_NoPerturb_std[i] = np.std(q1_3_NoPerturb[:,i])/(np.sqrt(1000))
######################################################################
######################################################################
q2_1_NoPerturb_mean = np.zeros(horizon)
q2_1_NoPerturb_std = np.zeros(horizon)

for i in range(horizon):

    q2_1_NoPerturb_mean[i] = np.mean(q2_1_NoPerturb[:,i])
    q2_1_NoPerturb_std[i] = np.std(q2_1_NoPerturb[:,i])/(np.sqrt(1000))
######################################################################
q2_2_NoPerturb_mean = np.zeros(horizon)
q2_2_NoPerturb_std = np.zeros(horizon)

for i in range(horizon):

    q2_2_NoPerturb_mean[i] = np.mean(q2_2_NoPerturb[:,i])
    q2_2_NoPerturb_std[i] = np.std(q2_2_NoPerturb[:,i])/(np.sqrt(1000))
######################################################################
q2_3_NoPerturb_mean = np.zeros(horizon)
q2_3_NoPerturb_std = np.zeros(horizon)

for i in range(horizon):

    q2_3_NoPerturb_mean[i] = np.mean(q2_3_NoPerturb[:,i])
    q2_3_NoPerturb_std[i] = np.std(q2_3_NoPerturb[:,i])/(np.sqrt(1000))
######################################################################
######################################################################
q3_1_NoPerturb_mean = np.zeros(horizon)
q3_1_NoPerturb_std = np.zeros(horizon)

for i in range(horizon):

    q3_1_NoPerturb_mean[i] = np.mean(q3_1_NoPerturb[:,i])
    q3_1_NoPerturb_std[i] = np.std(q3_1_NoPerturb[:,i])/(np.sqrt(1000))
######################################################################
q3_2_NoPerturb_mean = np.zeros(horizon)
q3_2_NoPerturb_std = np.zeros(horizon)

for i in range(horizon):

    q3_2_NoPerturb_mean[i] = np.mean(q3_2_NoPerturb[:,i])
    q3_2_NoPerturb_std[i] = np.std(q3_2_NoPerturb[:,i])/(np.sqrt(1000))
######################################################################
q3_3_NoPerturb_mean = np.zeros(horizon)
q3_3_NoPerturb_std = np.zeros(horizon)

for i in range(horizon):

    q3_3_NoPerturb_mean[i] = np.mean(q3_3_NoPerturb[:,i])
    q3_3_NoPerturb_std[i] = np.std(q3_3_NoPerturb[:,i])/(np.sqrt(1000))
######################################################################
######################################################################
q4_1_NoPerturb_mean = np.zeros(horizon)
q4_1_NoPerturb_std = np.zeros(horizon)

for i in range(horizon):

    q4_1_NoPerturb_mean[i] = np.mean(q4_1_NoPerturb[:,i])
    q4_1_NoPerturb_std[i] = np.std(q4_1_NoPerturb[:,i])/(np.sqrt(1000))
######################################################################
q4_2_NoPerturb_mean = np.zeros(horizon)
q4_2_NoPerturb_std = np.zeros(horizon)

for i in range(horizon):

    q4_2_NoPerturb_mean[i] = np.mean(q4_2_NoPerturb[:,i])
    q4_2_NoPerturb_std[i] = np.std(q4_2_NoPerturb[:,i])/(np.sqrt(1000))
######################################################################
q4_3_NoPerturb_mean = np.zeros(horizon)
q4_3_NoPerturb_std = np.zeros(horizon)

for i in range(horizon):

    q4_3_NoPerturb_mean[i] = np.mean(q4_3_NoPerturb[:,i])
    q4_3_NoPerturb_std[i] = np.std(q4_3_NoPerturb[:,i])/(np.sqrt(1000))
######################################################################
######################################################################
q5_1_NoPerturb_mean = np.zeros(horizon)
q5_1_NoPerturb_std = np.zeros(horizon)

for i in range(horizon):

    q5_1_NoPerturb_mean[i] = np.mean(q5_1_NoPerturb[:,i])
    q5_1_NoPerturb_std[i] = np.std(q5_1_NoPerturb[:,i])/(np.sqrt(1000))
######################################################################
q5_2_NoPerturb_mean = np.zeros(horizon)
q5_2_NoPerturb_std = np.zeros(horizon)

for i in range(horizon):

    q5_2_NoPerturb_mean[i] = np.mean(q5_2_NoPerturb[:,i])
    q5_2_NoPerturb_std[i] = np.std(q5_2_NoPerturb[:,i])/(np.sqrt(1000))
######################################################################
q5_3_NoPerturb_mean = np.zeros(horizon)
q5_3_NoPerturb_std = np.zeros(horizon)

for i in range(horizon):

    q5_3_NoPerturb_mean[i] = np.mean(q5_3_NoPerturb[:,i])
    q5_3_NoPerturb_std[i] = np.std(q5_3_NoPerturb[:,i])/(np.sqrt(1000))
######################################################################
######################################################################
######################################################################

total_episodes = total_episodes + 1

# plt.style.use('seaborn-darkgrid')
# #plt.rcParams['font.family'] = 'Times New Roman'
# font = {'size': 12}
# plt.rc('font', **

font = {'size'   : 8}
plt.rc('font', **font)

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.color'] = '#d3d3db'
plt.rcParams['axes.linewidth'] = 1.1
# plt.rcParams['font.family'] = 'Times New Roman'

# plt.rcParams.update({
#   "text.usetex": True,
#   "font.family": "Times"
# })

# plt.rcParams['text.usetex'] = True
# plt.rcParams['font.family'] = 'Times New Roman'
# plt.rcParams['text.usetex'] = False

#plt.xticks(np.arange(101))
# plt.yticks([0, 0.33, 0.66, 1])

plt.subplot(3, 5, 1)

plt.fill_between(total_episodes, q1_1_ours_mean - 1.96*q1_1_ours_std, q1_1_ours_mean + 1.96*q1_1_ours_std, alpha=0.2, color='k')
plt.plot(total_episodes, q1_1_ours_mean, ls='--', color='k', label='$q_{1}$')

plt.fill_between(total_episodes, q1_2_ours_mean - 1.96*q1_2_ours_std, q1_2_ours_mean + 1.96*q1_2_ours_std, alpha=0.2, color='b')
plt.plot(total_episodes, q1_2_ours_mean, ls=':', color='b', label='$q_{1}\'$')

plt.fill_between(total_episodes, q1_3_ours_mean - 1.96*q1_3_ours_std, q1_3_ours_mean + 1.96*q1_3_ours_std, alpha=0.2, color='r')
plt.plot(total_episodes, q1_3_ours_mean, ls='-.', color='r', label='$1-q_{1}-q_{1}\'$')

ax = plt.gca()
#ax.axes.xaxis.set_visible(False)

plt.xlim([-0.5,49+1])
plt.xticks([1,25,50])
plt.yticks([0, 0.5, 1])
plt.grid(True)
ax.set_xticklabels([])

plt.ylabel('Proposed Policy')
plt.title('$r_{83}(+1)$')#, font = 'Times New Roman')
###########################################################################################
plt.subplot(3, 5, 2)

plt.fill_between(total_episodes, q2_1_ours_mean - 1.96*q2_1_ours_std, q2_1_ours_mean + 1.96*q2_1_ours_std, alpha=0.2, color='k')
plt.plot(total_episodes, q2_1_ours_mean, ls='--', color='k', label='$q_{1}$')

plt.fill_between(total_episodes, q2_2_ours_mean - 1.96*q2_2_ours_std, q2_2_ours_mean + 1.96*q2_2_ours_std, alpha=0.2, color='b')
plt.plot(total_episodes, q2_2_ours_mean, ls=':', color='b', label='$q_{1}\'$')

plt.fill_between(total_episodes, q2_3_ours_mean - 1.96*q2_3_ours_std, q2_3_ours_mean + 1.96*q2_3_ours_std, alpha=0.2, color='r')
plt.plot(total_episodes, q2_3_ours_mean, ls='-.', color='r', label='$1-q_{1}-q_{1}\'$')

#plt.legend(loc='lower right')
ax = plt.gca()
# ax.axes.xaxis.set_visible(False)
# ax.axes.yaxis.set_visible(False)

plt.xlim([-0.5,49+1])
plt.xticks([1,25,50])
plt.yticks([0, 0.5, 1])
plt.grid(True)
ax.set_xticklabels([])
ax.set_yticklabels([])

plt.title('$r_{54}(+1)$ ')
###########################################################################################
plt.subplot(3, 5, 3)

plt.fill_between(total_episodes, q3_1_ours_mean - 1.96*q3_1_ours_std, q3_1_ours_mean + 1.96*q3_1_ours_std, alpha=0.2, color='k')
plt.plot(total_episodes, q3_1_ours_mean, ls='--', color='k', label='Avg. Posterior Probability of Being -1')#'$\mu$'

plt.fill_between(total_episodes, q3_2_ours_mean - 1.96*q3_2_ours_std, q3_2_ours_mean + 1.96*q3_2_ours_std, alpha=0.2, color='b')
plt.plot(total_episodes, q3_2_ours_mean, ls=':', color='b', label='Avg. Posterior Probability of Being 0')#'$\mu\'$'

plt.fill_between(total_episodes, q3_3_ours_mean - 1.96*q3_3_ours_std, q3_3_ours_mean + 1.96*q3_3_ours_std, alpha=0.2, color='r')
plt.plot(total_episodes, q3_3_ours_mean, ls='-.', color='r', label='Avg. Posterior Probability of Being +1')#'$1-\mu-\mu\'$'

#plt.legend(loc='lower right')
ax = plt.gca()
# ax.axes.xaxis.set_visible(False)
# ax.axes.yaxis.set_visible(False)

plt.xlim([-0.5,49+1])
plt.xticks([1,25,50])
plt.yticks([0, 0.5, 1])
plt.grid(True)
ax.set_xticklabels([])
ax.set_yticklabels([])

#ax.legend(loc='upper center', bbox_to_anchor=(0.5, +1.90), fancybox=True, shadow=True, ncol=3)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.6), fancybox=True, shadow=True, ncol=3)
plt.title('$r_{35}(-1)$ ')
###########################################################################################
plt.subplot(3, 5, 4)

plt.fill_between(total_episodes, q4_1_ours_mean - 1.96*q4_1_ours_std, q4_1_ours_mean + 1.96*q4_1_ours_std, alpha=0.2, color='k')
plt.plot(total_episodes, q4_1_ours_mean, ls='--', color='k', label='$q_{1}$')

plt.fill_between(total_episodes, q4_2_ours_mean - 1.96*q4_2_ours_std, q4_2_ours_mean + 1.96*q4_2_ours_std, alpha=0.2, color='b')
plt.plot(total_episodes, q4_2_ours_mean, ls=':', color='b', label='$q_{1}\'$')

plt.fill_between(total_episodes, q4_3_ours_mean - 1.96*q4_3_ours_std, q4_3_ours_mean + 1.96*q4_3_ours_std, alpha=0.2, color='r')
plt.plot(total_episodes, q4_3_ours_mean, ls='-.', color='r', label='$1-q_{1}-q_{1}\'$')

#plt.legend(loc='lower right')
ax = plt.gca()
# ax.axes.xaxis.set_visible(False)
# ax.axes.yaxis.set_visible(False)

plt.xlim([-0.5,49+1])
plt.xticks([1,25,50])
plt.yticks([0, 0.5, 1])
plt.grid(True)
ax.set_xticklabels([])
ax.set_yticklabels([])

plt.title('$r_{96}(+1)$ ')
###########################################################################################
plt.subplot(3, 5, 5)

plt.fill_between(total_episodes, q5_1_ours_mean - 1.96*q5_1_ours_std, q5_1_ours_mean + 1.96*q5_1_ours_std, alpha=0.2, color='k')
plt.plot(total_episodes, q5_1_ours_mean, ls='--', color='k', label='$q_{1}$')

plt.fill_between(total_episodes, q5_2_ours_mean - 1.96*q5_2_ours_std, q5_2_ours_mean + 1.96*q5_2_ours_std, alpha=0.2, color='b')
plt.plot(total_episodes, q5_2_ours_mean, ls=':', color='b', label='$q_{1}\'$')

plt.fill_between(total_episodes, q5_3_ours_mean - 1.96*q5_3_ours_std, q5_3_ours_mean + 1.96*q5_3_ours_std, alpha=0.2, color='r')
plt.plot(total_episodes, q5_3_ours_mean, ls='-.', color='r', label='$1-q_{1}-q_{1}\'$')

#plt.legend(loc='lower right')
ax = plt.gca()
# ax.axes.xaxis.set_visible(False)
# ax.axes.yaxis.set_visible(False)

plt.xlim([-0.5,49+1])
plt.xticks([1,25,50])
plt.yticks([0, 0.5, 1])
plt.grid(True)
ax.set_xticklabels([])
ax.set_yticklabels([])

plt.title('$r_{67}(-1)$')
##########################################################################################
##########################################################################################
##########################################################################################
plt.subplot(3, 5, 6)

plt.fill_between(total_episodes, q1_1_random_mean - 1.96*q1_1_random_std, q1_1_random_mean + 1.96*q1_1_random_std, alpha=0.2, color='k')
plt.plot(total_episodes, q1_1_random_mean, ls='--', color='k', label='$q_{1}$')

plt.fill_between(total_episodes, q1_2_random_mean - 1.96*q1_2_random_std, q1_2_random_mean + 1.96*q1_2_random_std, alpha=0.2, color='b')
plt.plot(total_episodes, q1_2_random_mean, ls=':', color='b', label='$q_{1}\'$')

plt.fill_between(total_episodes, q1_3_random_mean - 1.96*q1_3_random_std, q1_3_random_mean + 1.96*q1_3_random_std, alpha=0.2, color='r')
plt.plot(total_episodes, q1_3_random_mean, ls='-.', color='r', label='$1-q_{1}-q_{1}\'$')

ax = plt.gca()
#ax.axes.xaxis.set_visible(False)

plt.xlim([-0.5,49+1])
plt.xticks([1,25,50])
plt.yticks([0, 0.5, 1])
plt.ylim([0, 1.03])
plt.grid(True)
ax.set_xticklabels([])

plt.ylabel('EIG Policy')
###########################################################################################
plt.subplot(3, 5, 7)

plt.fill_between(total_episodes, q2_1_random_mean - 1.96*q2_1_random_std, q2_1_random_mean + 1.96*q2_1_random_std, alpha=0.2, color='k')
plt.plot(total_episodes, q2_1_random_mean, ls='--', color='k', label='$q_{1}$')

plt.fill_between(total_episodes, q2_2_random_mean - 1.96*q2_2_random_std, q2_2_random_mean + 1.96*q2_2_random_std, alpha=0.2, color='b')
plt.plot(total_episodes, q2_2_random_mean, ls=':', color='b', label='$q_{1}\'$')

plt.fill_between(total_episodes, q2_3_random_mean - 1.96*q2_3_random_std, q2_3_random_mean + 1.96*q2_3_random_std, alpha=0.2, color='r')
plt.plot(total_episodes, q2_3_random_mean, ls='-.', color='r', label='$1-q_{1}-q_{1}\'$')

#plt.legend(loc='lower right')
ax = plt.gca()
# ax.axes.xaxis.set_visible(False)
# ax.axes.yaxis.set_visible(False)

plt.xlim([-0.5,49+1])
plt.xticks([1,25,50])
plt.yticks([0, 0.5, 1])
plt.ylim([0, 1.03])
plt.grid(True)
ax.set_xticklabels([])
ax.set_yticklabels([])
###########################################################################################
plt.subplot(3, 5, 8)

plt.fill_between(total_episodes, q3_1_random_mean - 1.96*q3_1_random_std, q3_1_random_mean + 1.96*q3_1_random_std, alpha=0.2, color='k')
plt.plot(total_episodes, q3_1_random_mean, ls='--', color='k', label='$q_{1}$')

plt.fill_between(total_episodes, q3_2_random_mean - 1.96*q3_2_random_std, q3_2_random_mean + 1.96*q3_2_random_std, alpha=0.2, color='b')
plt.plot(total_episodes, q3_2_random_mean, ls=':', color='b', label='$q_{1}\'$')

plt.fill_between(total_episodes, q3_3_random_mean - 1.96*q3_3_random_std, q3_3_random_mean + 1.96*q3_3_random_std, alpha=0.2, color='r')
plt.plot(total_episodes, q3_3_random_mean, ls='-.', color='r', label='$1-q_{1}-q_{1}\'$')

#plt.legend(loc='lower right')
ax = plt.gca()
# ax.axes.xaxis.set_visible(False)
# ax.axes.yaxis.set_visible(False)

plt.xlim([-0.5,49+1])
plt.xticks([1,25,50])
plt.yticks([0, 0.5, 1])
plt.ylim([0, 1.03])
plt.grid(True)
ax.set_xticklabels([])
ax.set_yticklabels([])
###########################################################################################
plt.subplot(3, 5, 9)

plt.fill_between(total_episodes, q4_1_random_mean - 1.96*q4_1_random_std, q4_1_random_mean + 1.96*q4_1_random_std, alpha=0.2, color='k')
plt.plot(total_episodes, q4_1_random_mean, ls='--', color='k', label='$q_{1}$')

plt.fill_between(total_episodes, q4_2_random_mean - 1.96*q4_2_random_std, q4_2_random_mean + 1.96*q4_2_random_std, alpha=0.2, color='b')
plt.plot(total_episodes, q4_2_random_mean, ls=':', color='b', label='$q_{1}\'$')

plt.fill_between(total_episodes, q4_3_random_mean - 1.96*q4_3_random_std, q4_3_random_mean + 1.96*q4_3_random_std, alpha=0.2, color='r')
plt.plot(total_episodes, q4_3_random_mean, ls='-.', color='r', label='$1-q_{1}-q_{1}\'$')

#plt.legend(loc='lower right')
ax = plt.gca()
# ax.axes.xaxis.set_visible(False)
# ax.axes.yaxis.set_visible(False)

plt.xlim([-0.5,49+1])
plt.xticks([1,25,50])
plt.yticks([0, 0.5, 1])
plt.ylim([0, 1.03])
plt.grid(True)
ax.set_xticklabels([])
ax.set_yticklabels([])
###########################################################################################
plt.subplot(3, 5, 10)

plt.fill_between(total_episodes, q5_1_random_mean - 1.96*q5_1_random_std, q5_1_random_mean + 1.96*q5_1_random_std, alpha=0.2, color='k')
plt.plot(total_episodes, q5_1_random_mean, ls='--', color='k', label='$q_{1}$')

plt.fill_between(total_episodes, q5_2_random_mean - 1.96*q5_2_random_std, q5_2_random_mean + 1.96*q5_2_random_std, alpha=0.2, color='b')
plt.plot(total_episodes, q5_2_random_mean, ls=':', color='b', label='$q_{1}\'$')

plt.fill_between(total_episodes, q5_3_random_mean - 1.96*q5_3_random_std, q5_3_random_mean + 1.96*q5_3_random_std, alpha=0.2, color='r')
plt.plot(total_episodes, q5_3_random_mean, ls='-.', color='r', label='$1-q_{1}-q_{1}\'$')

#plt.legend(loc='lower right')
ax = plt.gca()
# ax.axes.xaxis.set_visible(False)
# ax.axes.yaxis.set_visible(False)

plt.xlim([-0.5,49+1])
plt.xticks([1,25,50])
plt.yticks([0, 0.5, 1])
plt.ylim([0, 1.03])
plt.grid(True)
ax.set_xticklabels([])
ax.set_yticklabels([])
##########################################################################################
##########################################################################################
##########################################################################################
plt.subplot(3, 5, 11)

plt.fill_between(total_episodes, q1_1_NoPerturb_mean - 1.96*q1_1_NoPerturb_std, q1_1_NoPerturb_mean + 1.96*q1_1_NoPerturb_std, alpha=0.2, color='k')
plt.plot(total_episodes, q1_1_NoPerturb_mean, ls='--', color='k', label='$q_{1}$')

plt.fill_between(total_episodes, q1_2_NoPerturb_mean - 1.96*q1_2_NoPerturb_std, q1_2_NoPerturb_mean + 1.96*q1_2_NoPerturb_std, alpha=0.2, color='b')
plt.plot(total_episodes, q1_2_NoPerturb_mean, ls=':', color='b', label='$q_{1}\'$')

plt.fill_between(total_episodes, q1_3_NoPerturb_mean - 1.96*q1_3_NoPerturb_std, q1_3_NoPerturb_mean + 1.96*q1_3_NoPerturb_std, alpha=0.2, color='r')
plt.plot(total_episodes, q1_3_NoPerturb_mean, ls='-.', color='r', label='$1-q_{1}-q_{1}\'$')

ax = plt.gca()
plt.xlim([-0.5,49+1])
plt.xticks([1,25,50])
plt.yticks([0, 0.5, 1])
plt.ylim([0,1.03])
#ax.axes.xaxis.set_visible(False)

plt.ylabel('No Perturbation')
#ax.yaxis.set_label_coords(-0.45, 0.4)
###########################################################################################
plt.subplot(3, 5, 12)

plt.fill_between(total_episodes, q2_1_NoPerturb_mean - 1.96*q2_1_NoPerturb_std, q2_1_NoPerturb_mean + 1.96*q2_1_NoPerturb_std, alpha=0.2, color='k')
plt.plot(total_episodes, q2_1_NoPerturb_mean, ls='--', color='k', label='$q_{1}$')

plt.fill_between(total_episodes, q2_2_NoPerturb_mean - 1.96*q2_2_NoPerturb_std, q2_2_NoPerturb_mean + 1.96*q2_2_NoPerturb_std, alpha=0.2, color='b')
plt.plot(total_episodes, q2_2_NoPerturb_mean, ls=':', color='b', label='$q_{1}\'$')

plt.fill_between(total_episodes, q2_3_NoPerturb_mean - 1.96*q2_3_NoPerturb_std, q2_3_NoPerturb_mean + 1.96*q2_3_NoPerturb_std, alpha=0.2, color='r')
plt.plot(total_episodes, q2_3_NoPerturb_mean, ls='-.', color='r', label='$1-q_{1}-q_{1}\'$')

#plt.legend(loc='lower right')
ax = plt.gca()
#ax.axes.xaxis.set_visible(False)
#ax.axes.yaxis.set_visible(False)

plt.xlim([-0.5,49+1])
plt.xticks([1,25,50])
plt.yticks([0, 0.5, 1])
plt.grid(True)
ax.set_yticklabels([])

plt.ylim([0,1.03])
###########################################################################################
plt.subplot(3, 5, 13)

plt.fill_between(total_episodes, q3_1_NoPerturb_mean - 1.96*q3_1_NoPerturb_std, q3_1_NoPerturb_mean + 1.96*q3_1_NoPerturb_std, alpha=0.2, color='k')
plt.plot(total_episodes, q3_1_NoPerturb_mean, ls='--', color='k', label='$q_{1}$')

plt.fill_between(total_episodes, q3_2_NoPerturb_mean - 1.96*q3_2_NoPerturb_std, q3_2_NoPerturb_mean + 1.96*q3_2_NoPerturb_std, alpha=0.2, color='b')
plt.plot(total_episodes, q3_2_NoPerturb_mean, ls=':', color='b', label='$q_{1}\'$')

plt.fill_between(total_episodes, q3_3_NoPerturb_mean - 1.96*q3_3_NoPerturb_std, q3_3_NoPerturb_mean + 1.96*q3_3_NoPerturb_std, alpha=0.2, color='r')
plt.plot(total_episodes, q3_3_NoPerturb_mean, ls='-.', color='r', label='$1-q_{1}-q_{1}\'$')

#plt.legend(loc='lower right')
ax = plt.gca()
#ax.axes.xaxis.set_visible(False)
#ax.axes.yaxis.set_visible(False)

plt.xlim([-0.5,49+1])
plt.xticks([1,25,50])
plt.yticks([0, 0.5, 1])
plt.grid(True)
ax.set_yticklabels([])

plt.ylim([0,1.03])


plt.xlabel('Number of Data')
#ax.xaxis.set_label_coords(0.5, -0.45)
#ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), fancybox=True, shadow=True, ncol=3)

###########################################################################################
plt.subplot(3, 5, 14)

plt.fill_between(total_episodes, q4_1_NoPerturb_mean - 1.96*q4_1_NoPerturb_std, q4_1_NoPerturb_mean + 1.96*q4_1_NoPerturb_std, alpha=0.2, color='k')
plt.plot(total_episodes, q4_1_NoPerturb_mean, ls='--', color='k', label='$q_{1}$')

plt.fill_between(total_episodes, q4_2_NoPerturb_mean - 1.96*q4_2_NoPerturb_std, q4_2_NoPerturb_mean + 1.96*q4_2_NoPerturb_std, alpha=0.2, color='b')
plt.plot(total_episodes, q4_2_NoPerturb_mean, ls=':', color='b', label='$q_{1}\'$')

plt.fill_between(total_episodes, q4_3_NoPerturb_mean - 1.96*q4_3_NoPerturb_std, q4_3_NoPerturb_mean + 1.96*q4_3_NoPerturb_std, alpha=0.2, color='r')
plt.plot(total_episodes, q4_3_NoPerturb_mean, ls='-.', color='r', label='$1-q_{1}-q_{1}\'$')

#plt.legend(loc='lower right')
ax = plt.gca()
#ax.axes.xaxis.set_visible(False)
#ax.axes.yaxis.set_visible(False)

plt.xlim([-0.5,49+1])
plt.xticks([1,25,50])
plt.yticks([0, 0.5, 1])
plt.grid(True)
ax.set_yticklabels([])

plt.ylim([0,1.03])
###########################################################################################
plt.subplot(3, 5, 15)

plt.fill_between(total_episodes, q5_1_NoPerturb_mean - 1.96*q5_1_NoPerturb_std, q5_1_NoPerturb_mean + 1.96*q5_1_NoPerturb_std, alpha=0.2, color='k')
plt.plot(total_episodes, q5_1_NoPerturb_mean, ls='--', color='k', label='$q_{1}$')

plt.fill_between(total_episodes, q5_2_NoPerturb_mean - 1.96*q5_2_NoPerturb_std, q5_2_NoPerturb_mean + 1.96*q5_2_NoPerturb_std, alpha=0.2, color='b')
plt.plot(total_episodes, q5_2_NoPerturb_mean, ls=':', color='b', label='$q_{1}\'$')

plt.fill_between(total_episodes, q5_3_NoPerturb_mean - 1.96*q5_3_NoPerturb_std, q5_3_NoPerturb_mean + 1.96*q5_3_NoPerturb_std, alpha=0.2, color='r')
plt.plot(total_episodes, q5_3_NoPerturb_mean, ls='-.', color='r', label='$1-q_{1}-q_{1}\'$')

#plt.legend(loc='lower right')
ax = plt.gca()
#ax.axes.xaxis.set_visible(False)
#ax.axes.yaxis.set_visible(False)

plt.xlim([-0.5,49+1])
plt.xticks([1,25,50])
plt.yticks([0, 0.5, 1])
plt.grid(True)
ax.set_yticklabels([])

plt.ylim([0,1.03])
##########################################################################################
##########################################################################################
##########################################################################################

#plt.legend(bbox_to_anchor = (0.07, 0))
#plt.legend(loc='lower right')
#ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), fancybox=True, shadow=True, ncol=3)
#plt.tight_layout(pad=2)
#plt.tight_layout(rect=[0,0,.8,1])

plt.savefig("BaseCase_Qvalues_Final1.png", dpi=300, bbox_inches = "tight")

plt.show()
